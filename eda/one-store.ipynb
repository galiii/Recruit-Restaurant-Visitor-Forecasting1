# %%
import numpy as np #It provides a high-performance multidimensional array object, and tools for working with these arrays
import pandas as pd #
from subprocess import check_output
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
import matplotlib
matplotlib.style.use('ggplot')

# %%
# Data Aggregation
airres = pd.read_csv('../input/air_reserve.csv')
airstore = pd.read_csv('../input/air_store_info.csv')
#hpgres = pd.read_csv('../input/hpg_reserve.csv')
#hpgstore = pd.read_csv('../input/hpg_store_info.csv')
airvisit = pd.read_csv('../input/air_visit_data.csv')
dates = pd.read_csv('../input/date_info.csv')
#wd = pd.read_csv('../input/WeatherData.csv')
rel = pd.read_csv('../input/store_id_relation.csv')
#test = pd.read_csv('../input/sample_submission.csv')

# %% [markdown]
# air_877f79706adbfb06 in this store
# * from the **air_visit_data** we have  **383 visits** from **1-1-2016 to 22-4-2017**
# * from the **air_store_info** we know it's located in **Tōkyō** and **Japanese food**
# * from the **air_reserve** we know we have (visit_datetime	reserve_datetime) **1061**

# %%
air_877f79706adbfb06 = airvisit.copy()

air_877f79706adbfb06 = air_877f79706adbfb06[air_877f79706adbfb06['air_store_id'] == 'air_877f79706adbfb06']
v_count = len(air_877f79706adbfb06)

# %%
air_877f79706adbfb06
#v_count
#len(air_877f79706adbfb06['visit_date'].unique())
# Out:
#                air_store_id  visit_date  visitors
# 74720  air_877f79706adbfb06  2016-01-01         3
# 74721  air_877f79706adbfb06  2016-01-02        12
# 74722  air_877f79706adbfb06  2016-01-08        17
# 74723  air_877f79706adbfb06  2016-01-09         8
# 74724  air_877f79706adbfb06  2016-01-12        15
# 74725  air_877f79706adbfb06  2016-01-13        17
# 74726  air_877f79706adbfb06  2016-01-14        15
# 74727  air_877f79706adbfb06  2016-01-15        19
# 74728  air_877f79706adbfb06  2016-01-16         8
# 74729  air_877f79706adbfb06  2016-01-18        25
# 74730  air_877f79706adbfb06  2016-01-19        11
# 74731  air_877f79706adbfb06  2016-01-20        12
# 74732  air_877f79706adbfb06  2016-01-21         9
# 74733  air_877f79706adbfb06  2016-01-22         8
# 74734  air_877f79706adbfb06  2016-01-25        16
# 74735  air_877f79706adbfb06  2016-01-26         9
# 74736  air_877f79706adbfb06  2016-01-27        12
# 74737  air_877f79706adbfb06  2016-01-28        10
# ...

# %%
bir_877f79706adbfb06 = airstore[airstore['air_store_id']=='air_877f79706adbfb06']
bir_877f79706adbfb06
# Out:
#              air_store_id air_genre_name                 air_area_name  \
# 707  air_877f79706adbfb06  Japanese food  Tōkyō-to Minato-ku Shibakōen
#
#       latitude   longitude
# 707  35.658068  139.751599

# %%
cir_877f79706adbfb06 = airres.copy()
cir_877f79706adbfb06  = cir_877f79706adbfb06[cir_877f79706adbfb06['air_store_id'] == 'air_877f79706adbfb06']

vdt = pd.to_datetime(cir_877f79706adbfb06.visit_datetime)

cir_877f79706adbfb06['vd']=vdt.dt.date


v2_count = len(cir_877f79706adbfb06)

# %%
#v2_count
#dir_877f79706adbfb06 = cir_877f79706adbfb06['reserve_datetime'].sort_values()
#cir_877f79706adbfb06
#eir_877f79706adbfb06 = cir_877f79706adbfb06[cir_877f79706adbfb06['vd'] == '2016-01-02']
cir_877f79706adbfb06
# Out:
#                air_store_id       visit_datetime     reserve_datetime  \
# 0      air_877f79706adbfb06  2016-01-01 19:00:00  2016-01-01 16:00:00
# 3      air_877f79706adbfb06  2016-01-01 20:00:00  2016-01-01 16:00:00
# 19     air_877f79706adbfb06  2016-01-02 18:00:00  2016-01-01 16:00:00
# 26     air_877f79706adbfb06  2016-01-02 21:00:00  2016-01-01 16:00:00
# 272    air_877f79706adbfb06  2016-01-08 21:00:00  2016-01-04 20:00:00
# 273    air_877f79706adbfb06  2016-01-08 21:00:00  2016-01-08 21:00:00
# 274    air_877f79706adbfb06  2016-01-08 21:00:00  2016-01-05 13:00:00
# 398    air_877f79706adbfb06  2016-01-09 20:00:00  2016-01-06 23:00:00
# 410    air_877f79706adbfb06  2016-01-09 21:00:00  2016-01-09 21:00:00
# 412    air_877f79706adbfb06  2016-01-09 22:00:00  2016-01-05 12:00:00
# 592    air_877f79706adbfb06  2016-01-12 21:00:00  2016-01-12 18:00:00
# 593    air_877f79706adbfb06  2016-01-12 21:00:00  2016-01-12 18:00:00
# ...

# %%
cir_877f79706adbfb06[cir_877f79706adbfb06['vd'] == (2016,1,2)]
# Out:
# Empty DataFrame
# Columns: [air_store_id, visit_datetime, reserve_datetime, reserve_visitors, vd]
# Index: []
