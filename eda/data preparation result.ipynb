# %% [markdown]
# ## Variable engineering

# %% [markdown]
#  The aim of this challenge is to predict the future numbers of restaurant visitors. This makes it a Time Series Forecasting problem. The data was collected from Japanese restaurants. We have chosen this project, because the data set is small and easily accessible.<br>
#  The project is very important and interesting for us because it is a real data set, and real business problem.

# %% [markdown]
# In this section, we create new variables.Change their types.Check the relevance of each variable for the future model.<br>
# let's try!!!

# %%
# Load libraries
import numpy as np 
import pandas as pd 
from subprocess import check_output
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# The training data covers the dates from 2016 until April 2017. The test set covers the last week of April and May of 2017. The test set is split based on time (the public fold coming first, the private fold following the public) and covers a chosen subset of the air restaurants. Note that the test set intentionally spans a holiday week in Japan called the "Golden Week."

# %%
# Data Aggregation
airres = pd.read_csv('../input/air_reserve.csv')
airstore = pd.read_csv('../input/air_store_info.csv')
hpgres = pd.read_csv('../input/hpg_reserve.csv')
hpgstore = pd.read_csv('../input/hpg_store_info.csv')
airvisit = pd.read_csv('../input/air_visit_data.csv')
dates = pd.read_csv('../input/date_info.csv')
wd = pd.read_csv('../input/WeatherData.csv')
rel = pd.read_csv('../input/store_id_relation.csv')
test = pd.read_csv('../input/sample_submission.csv')

# %%
airvisit.tail(1)
# Out:
#                 air_store_id  visit_date  visitors
# 252107  air_24e8414b9b07decb  2017-04-22         5

# %%
airres.head(1)
# Out:
#            air_store_id       visit_datetime     reserve_datetime  \
# 0  air_877f79706adbfb06  2016-01-01 19:00:00  2016-01-01 16:00:00
#
#    reserve_visitors
# 0                 1

# %%
hpgres.head(1)
# Out:
#            hpg_store_id       visit_datetime     reserve_datetime  \
# 0  hpg_c63f6f42e088e50f  2016-01-01 11:00:00  2016-01-01 09:00:00
#
#    reserve_visitors
# 0                 1

# %% [markdown]
#   ## In this chapter we will convert the date format and group by date reservation data.

# %% [markdown]
# #### in table <code>airres</code>
# ##### Having new columns
# * <code>vd</code> - visit datetime
# * <code>rd</code> - reserve datetime

# %%
#AIR
#airres = pd.read_csv('../input/air_reserve.csv')
vdt = pd.to_datetime(airres.visit_datetime)
rdt = pd.to_datetime(airres.reserve_datetime)
airres['vd']=vdt.dt.date # visit datetime ([])
airres['rd']=rdt.dt.date # reserve datetime

# %%
airres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92378 entries, 0 to 92377
# Data columns (total 6 columns):
# air_store_id        92378 non-null object
# visit_datetime      92378 non-null object
# reserve_datetime    92378 non-null object
# reserve_visitors    92378 non-null int64
# vd                  92378 non-null object
# rd                  92378 non-null object
# dtypes: int64(1), object(5)
# memory usage: 4.2+ MB

# %%
airres.head(1)
# Out:
#            air_store_id       visit_datetime     reserve_datetime  \
# 0  air_877f79706adbfb06  2016-01-01 19:00:00  2016-01-01 16:00:00
#
#    reserve_visitors          vd          rd
# 0                 1  2016-01-01  2016-01-01

# %% [markdown]
# The var we have
# * **air_store_id**
# * **visit_datetime**
# * **reserve_datetime**
# * **reserve_visitors** <br><br>
# New
# * **vd**
# * **rd**

# %% [markdown]
# ### new column <code>res_date_diff</code>
# the diffrence between when **reserve** was done and the **visit** was in **days**

# %%
# adding (r['vd'] - r['rd']).days to each value 
# axis = 1 or 'columns': apply function to each row.
airres['res_date_diff'] = airres.apply(lambda r: (r['vd'] - r['rd']).days, axis=1)

# %%
airres.head(1)
# Out:
#            air_store_id       visit_datetime     reserve_datetime  \
# 0  air_877f79706adbfb06  2016-01-01 19:00:00  2016-01-01 16:00:00
#
#    reserve_visitors          vd          rd  res_date_diff
# 0                 1  2016-01-01  2016-01-01              0

# %%
airres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92378 entries, 0 to 92377
# Data columns (total 7 columns):
# air_store_id        92378 non-null object
# visit_datetime      92378 non-null object
# reserve_datetime    92378 non-null object
# reserve_visitors    92378 non-null int64
# vd                  92378 non-null object
# rd                  92378 non-null object
# res_date_diff       92378 non-null int64
# dtypes: int64(2), object(5)
# memory usage: 4.9+ MB

# %% [markdown]
# The var we have
# * **air_store_id**
# * **visit_datetime**
# * **reserve_datetime**
# * **reserve_visitors**
# * **vd**
# * **rd** <br><br>
# New
# * **res_date_diff**

# %%
airres = airres.groupby(['air_store_id','vd'], as_index=False)\
[['res_date_diff', 'reserve_visitors']].sum().rename(columns={'visit_datetime':'visit_date'})

# %%
airres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29830 entries, 0 to 29829
# Data columns (total 4 columns):
# air_store_id        29830 non-null object
# vd                  29830 non-null object
# res_date_diff       29830 non-null int64
# reserve_visitors    29830 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 1.1+ MB

# %%
airres.head(1)
# Out:
#            air_store_id          vd  res_date_diff  reserve_visitors
# 0  air_00a91d42b08b08d9  2016-10-31              0                 2

# %%
airres.rename(columns={'vd':'visit_date'})
# Out:
#                air_store_id  visit_date  res_date_diff  reserve_visitors
# 0      air_00a91d42b08b08d9  2016-10-31              0                 2
# 1      air_00a91d42b08b08d9  2016-12-05              4                 9
# 2      air_00a91d42b08b08d9  2016-12-14              6                18
# 3      air_00a91d42b08b08d9  2016-12-17              6                 2
# 4      air_00a91d42b08b08d9  2016-12-20              2                 4
# 5      air_00a91d42b08b08d9  2017-02-18              5                 9
# 6      air_00a91d42b08b08d9  2017-02-23              2                12
# 7      air_00a91d42b08b08d9  2017-03-01             11                 3
# 8      air_00a91d42b08b08d9  2017-03-14              0                 4
# 9      air_00a91d42b08b08d9  2017-03-21              5                 3
# 10     air_00a91d42b08b08d9  2017-03-24              1                 2
# 11     air_00a91d42b08b08d9  2017-04-04              2                 2
# 12     air_0164b9927d20bcc3  2016-10-28             10                12
# 13     air_0164b9927d20bcc3  2016-11-01              5                10
# 14     air_0164b9927d20bcc3  2016-11-02              0                 3
# 15     air_0164b9927d20bcc3  2016-11-08              8                 9
# 16     air_0164b9927d20bcc3  2016-11-10             43                 6
# 17     air_0164b9927d20bcc3  2016-11-11              1                 4
# 18     air_0164b9927d20bcc3  2016-11-14             22                17
# 19     air_0164b9927d20bcc3  2016-11-15              4                 3
# 20     air_0164b9927d20bcc3  2016-11-16              0                 2
# 21     air_0164b9927d20bcc3  2016-11-18             13                13
# 22     air_0164b9927d20bcc3  2016-11-21              6                 3
# 23     air_0164b9927d20bcc3  2016-11-22             22                 9
# 24     air_0164b9927d20bcc3  2016-11-24              7                 2
# 25     air_0164b9927d20bcc3  2016-11-26             39                10
# 26     air_0164b9927d20bcc3  2016-11-28              1                 2
# 27     air_0164b9927d20bcc3  2016-12-02              0                 3
# 28     air_0164b9927d20bcc3  2016-12-05             11                 4
# 29     air_0164b9927d20bcc3  2016-12-06              1                 2
# ...                     ...         ...            ...               ...
# 29800  air_fea5dc9594450608  2017-03-08              5                 2
# 29801  air_fea5dc9594450608  2017-03-10              3                 3
# 29802  air_fea5dc9594450608  2017-03-11              3                 7
# 29803  air_fea5dc9594450608  2017-03-16              2                 3
# 29804  air_fea5dc9594450608  2017-03-17             30                11
# 29805  air_fea5dc9594450608  2017-03-18             49                10
# 29806  air_fea5dc9594450608  2017-03-21              0                 5
# 29807  air_fea5dc9594450608  2017-03-22              1                 2
# 29808  air_fea5dc9594450608  2017-03-23              0                 8
# 29809  air_fea5dc9594450608  2017-03-24              0                 2
# 29810  air_fea5dc9594450608  2017-03-25              2                 6
# 29811  air_fea5dc9594450608  2017-03-29             18                 2
# 29812  air_fea5dc9594450608  2017-03-30             15                 5
# 29813  air_fea5dc9594450608  2017-04-01              0                 2
# 29814  air_fea5dc9594450608  2017-04-05              6                 4
# 29815  air_fea5dc9594450608  2017-04-07              1                 2
# 29816  air_fea5dc9594450608  2017-04-08              6                 5
# 29817  air_fea5dc9594450608  2017-04-11              0                 4
# 29818  air_fea5dc9594450608  2017-04-12              1                 2
# 29819  air_fea5dc9594450608  2017-04-14              1                 2
# 29820  air_fea5dc9594450608  2017-04-15             10                 4
# 29821  air_fea5dc9594450608  2017-04-18              6                 2
# 29822  air_fea5dc9594450608  2017-04-19              0                 2
# 29823  air_fea5dc9594450608  2017-04-20              3                 6
# 29824  air_fea5dc9594450608  2017-04-21             29                10
# 29825  air_fea5dc9594450608  2017-04-22              0                 2
# 29826  air_fea5dc9594450608  2017-04-25              9                 2
# 29827  air_fea5dc9594450608  2017-04-28             29                 3
# 29828  air_fea5dc9594450608  2017-05-20             34                 6
# 29829  air_fee8dcf4d619598e  2017-01-09             16                 5
#
# [29830 rows x 4 columns]

# %%
airres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29830 entries, 0 to 29829
# Data columns (total 4 columns):
# air_store_id        29830 non-null object
# vd                  29830 non-null object
# res_date_diff       29830 non-null int64
# reserve_visitors    29830 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 1.1+ MB

# %%
airres.head(1)
# Out:
#            air_store_id          vd  res_date_diff  reserve_visitors
# 0  air_00a91d42b08b08d9  2016-10-31              0                 2

# %% [markdown]
# The final var in table **airres** is
# * **air_store_id**
# * **vd**
# * **res_date_diff**
# * **reserve_visitors**

# %%
# HPG
vdt = pd.to_datetime(hpgres.visit_datetime)
rdt = pd.to_datetime(hpgres.reserve_datetime)
hpgres['vd']=vdt.dt.date
hpgres['rd']=rdt.dt.date
hpgres.head(1)
# Out:
#            hpg_store_id       visit_datetime     reserve_datetime  \
# 0  hpg_c63f6f42e088e50f  2016-01-01 11:00:00  2016-01-01 09:00:00
#
#    reserve_visitors          vd          rd
# 0                 1  2016-01-01  2016-01-01

# %%
hpgres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000320 entries, 0 to 2000319
# Data columns (total 6 columns):
# hpg_store_id        object
# visit_datetime      object
# reserve_datetime    object
# reserve_visitors    int64
# vd                  object
# rd                  object
# dtypes: int64(1), object(5)
# memory usage: 91.6+ MB

# %%
hpgres['date_diff'] = hpgres.apply(lambda r: (r['vd'] - r['rd']).days, axis=1)

# %%
hpgres = hpgres.groupby(['hpg_store_id','vd'], as_index=False)\
[['date_diff', 'reserve_visitors']].sum().rename(columns={'visit_datetime':'visit_date'})

# %%
hpgres.head(2)
# Out:
#            hpg_store_id          vd  date_diff  reserve_visitors
# 0  hpg_001112ef76b9802c  2016-02-26         17                 9
# 1  hpg_001112ef76b9802c  2016-03-17         14                 3

# %%
hpgres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1355053 entries, 0 to 1355052
# Data columns (total 4 columns):
# hpg_store_id        1355053 non-null object
# vd                  1355053 non-null object
# date_diff           1355053 non-null int64
# reserve_visitors    1355053 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 51.7+ MB

# %% [markdown]
# After each section we check that there are no null values

# %% [markdown]
# ## Data aggregation

# %%
air = pd.merge(airres,airstore,on='air_store_id')
hpg = pd.merge(hpgres,hpgstore,on='hpg_store_id')
airrel = pd.merge(air,rel,how='left',on='air_store_id')
hpgrel = pd.merge(hpg,rel,how='left',on='hpg_store_id')
airrel.head(2)
# Out:
#            air_store_id          vd  res_date_diff  reserve_visitors  \
# 0  air_00a91d42b08b08d9  2016-10-31              0                 2
# 1  air_00a91d42b08b08d9  2016-12-05              4                 9
#
#    air_genre_name                    air_area_name   latitude   longitude  \
# 0  Italian/French  Tōkyō-to Chiyoda-ku Kudanminami  35.694003  139.753595
# 1  Italian/French  Tōkyō-to Chiyoda-ku Kudanminami  35.694003  139.753595
#
#            hpg_store_id
# 0  hpg_fbe603376b5980fc
# 1  hpg_fbe603376b5980fc

# %%
air.head(8)
# Out:
#            air_store_id          vd  res_date_diff  reserve_visitors  \
# 0  air_00a91d42b08b08d9  2016-10-31              0                 2
# 1  air_00a91d42b08b08d9  2016-12-05              4                 9
# 2  air_00a91d42b08b08d9  2016-12-14              6                18
# 3  air_00a91d42b08b08d9  2016-12-17              6                 2
# 4  air_00a91d42b08b08d9  2016-12-20              2                 4
# 5  air_00a91d42b08b08d9  2017-02-18              5                 9
# 6  air_00a91d42b08b08d9  2017-02-23              2                12
# 7  air_00a91d42b08b08d9  2017-03-01             11                 3
#
#    air_genre_name                    air_area_name   latitude   longitude
# 0  Italian/French  Tōkyō-to Chiyoda-ku Kudanminami  35.694003  139.753595
# 1  Italian/French  Tōkyō-to Chiyoda-ku Kudanminami  35.694003  139.753595
# 2  Italian/French  Tōkyō-to Chiyoda-ku Kudanminami  35.694003  139.753595
# 3  Italian/French  Tōkyō-to Chiyoda-ku Kudanminami  35.694003  139.753595
# 4  Italian/French  Tōkyō-to Chiyoda-ku Kudanminami  35.694003  139.753595
# 5  Italian/French  Tōkyō-to Chiyoda-ku Kudanminami  35.694003  139.753595
# 6  Italian/French  Tōkyō-to Chiyoda-ku Kudanminami  35.694003  139.753595
# 7  Italian/French  Tōkyō-to Chiyoda-ku Kudanminami  35.694003  139.753595

# %%
hpgrel.head(1)
# Out:
#            hpg_store_id          vd  date_diff  reserve_visitors  \
# 0  hpg_001ce40a1f873e4f  2016-01-13          3                 4
#
#    hpg_genre_name            hpg_area_name   latitude   longitude air_store_id
# 0  Japanese style  Hyōgo-ken Kōbe-shi None  34.692109  135.191698          NaN

# %%
hpgrel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 561109 entries, 0 to 561108
# Data columns (total 9 columns):
# hpg_store_id        561109 non-null object
# vd                  561109 non-null object
# date_diff           561109 non-null int64
# reserve_visitors    561109 non-null int64
# hpg_genre_name      561109 non-null object
# hpg_area_name       561109 non-null object
# latitude            561109 non-null float64
# longitude           561109 non-null float64
# air_store_id        8877 non-null object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 42.8+ MB

# %%
airrel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29830 entries, 0 to 29829
# Data columns (total 9 columns):
# air_store_id        29830 non-null object
# vd                  29830 non-null object
# res_date_diff       29830 non-null int64
# reserve_visitors    29830 non-null int64
# air_genre_name      29830 non-null object
# air_area_name       29830 non-null object
# latitude            29830 non-null float64
# longitude           29830 non-null float64
# hpg_store_id        12646 non-null object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 2.3+ MB

# %% [markdown]
# In this step, we see that there are very few intersections in the two systems AIR and HPG.

# %%
full = pd.merge(airrel,hpgrel,how='left')
print("there are ",len(air)," restaurants with AIR and ",len(hpg)," with HPG.",len(rel),' have both.')
# Out:
# there are  29830  restaurants with AIR and  561109  with HPG. 150  have both.

# %%
full.rename(columns={'vd':'visit_date'})
# Out:
#                air_store_id  visit_date  res_date_diff  reserve_visitors  \
# 0      air_00a91d42b08b08d9  2016-10-31              0                 2
# 1      air_00a91d42b08b08d9  2016-12-05              4                 9
# 2      air_00a91d42b08b08d9  2016-12-14              6                18
# 3      air_00a91d42b08b08d9  2016-12-17              6                 2
# 4      air_00a91d42b08b08d9  2016-12-20              2                 4
# 5      air_00a91d42b08b08d9  2017-02-18              5                 9
# 6      air_00a91d42b08b08d9  2017-02-23              2                12
# 7      air_00a91d42b08b08d9  2017-03-01             11                 3
# 8      air_00a91d42b08b08d9  2017-03-14              0                 4
# 9      air_00a91d42b08b08d9  2017-03-21              5                 3
# 10     air_00a91d42b08b08d9  2017-03-24              1                 2
# 11     air_00a91d42b08b08d9  2017-04-04              2                 2
# 12     air_0164b9927d20bcc3  2016-10-28             10                12
# 13     air_0164b9927d20bcc3  2016-11-01              5                10
# 14     air_0164b9927d20bcc3  2016-11-02              0                 3
# 15     air_0164b9927d20bcc3  2016-11-08              8                 9
# 16     air_0164b9927d20bcc3  2016-11-10             43                 6
# 17     air_0164b9927d20bcc3  2016-11-11              1                 4
# 18     air_0164b9927d20bcc3  2016-11-14             22                17
# 19     air_0164b9927d20bcc3  2016-11-15              4                 3
# 20     air_0164b9927d20bcc3  2016-11-16              0                 2
# 21     air_0164b9927d20bcc3  2016-11-18             13                13
# 22     air_0164b9927d20bcc3  2016-11-21              6                 3
# 23     air_0164b9927d20bcc3  2016-11-22             22                 9
# 24     air_0164b9927d20bcc3  2016-11-24              7                 2
# 25     air_0164b9927d20bcc3  2016-11-26             39                10
# 26     air_0164b9927d20bcc3  2016-11-28              1                 2
# 27     air_0164b9927d20bcc3  2016-12-02              0                 3
# 28     air_0164b9927d20bcc3  2016-12-05             11                 4
# 29     air_0164b9927d20bcc3  2016-12-06              1                 2
# ...                     ...         ...            ...               ...
# 29800  air_fea5dc9594450608  2017-03-08              5                 2
# 29801  air_fea5dc9594450608  2017-03-10              3                 3
# 29802  air_fea5dc9594450608  2017-03-11              3                 7
# 29803  air_fea5dc9594450608  2017-03-16              2                 3
# 29804  air_fea5dc9594450608  2017-03-17             30                11
# 29805  air_fea5dc9594450608  2017-03-18             49                10
# 29806  air_fea5dc9594450608  2017-03-21              0                 5
# 29807  air_fea5dc9594450608  2017-03-22              1                 2
# 29808  air_fea5dc9594450608  2017-03-23              0                 8
# 29809  air_fea5dc9594450608  2017-03-24              0                 2
# 29810  air_fea5dc9594450608  2017-03-25              2                 6
# 29811  air_fea5dc9594450608  2017-03-29             18                 2
# 29812  air_fea5dc9594450608  2017-03-30             15                 5
# 29813  air_fea5dc9594450608  2017-04-01              0                 2
# 29814  air_fea5dc9594450608  2017-04-05              6                 4
# 29815  air_fea5dc9594450608  2017-04-07              1                 2
# 29816  air_fea5dc9594450608  2017-04-08              6                 5
# 29817  air_fea5dc9594450608  2017-04-11              0                 4
# 29818  air_fea5dc9594450608  2017-04-12              1                 2
# 29819  air_fea5dc9594450608  2017-04-14              1                 2
# 29820  air_fea5dc9594450608  2017-04-15             10                 4
# 29821  air_fea5dc9594450608  2017-04-18              6                 2
# 29822  air_fea5dc9594450608  2017-04-19              0                 2
# 29823  air_fea5dc9594450608  2017-04-20              3                 6
# 29824  air_fea5dc9594450608  2017-04-21             29                10
# 29825  air_fea5dc9594450608  2017-04-22              0                 2
# 29826  air_fea5dc9594450608  2017-04-25              9                 2
# 29827  air_fea5dc9594450608  2017-04-28             29                 3
# 29828  air_fea5dc9594450608  2017-05-20             34                 6
# 29829  air_fee8dcf4d619598e  2017-01-09             16                 5
#
#        air_genre_name                            air_area_name   latitude  \
# 0      Italian/French          Tōkyō-to Chiyoda-ku Kudanminami  35.694003
# 1      Italian/French          Tōkyō-to Chiyoda-ku Kudanminami  35.694003
# 2      Italian/French          Tōkyō-to Chiyoda-ku Kudanminami  35.694003
# 3      Italian/French          Tōkyō-to Chiyoda-ku Kudanminami  35.694003
# 4      Italian/French          Tōkyō-to Chiyoda-ku Kudanminami  35.694003
# 5      Italian/French          Tōkyō-to Chiyoda-ku Kudanminami  35.694003
# 6      Italian/French          Tōkyō-to Chiyoda-ku Kudanminami  35.694003
# 7      Italian/French          Tōkyō-to Chiyoda-ku Kudanminami  35.694003
# 8      Italian/French          Tōkyō-to Chiyoda-ku Kudanminami  35.694003
# 9      Italian/French          Tōkyō-to Chiyoda-ku Kudanminami  35.694003
# 10     Italian/French          Tōkyō-to Chiyoda-ku Kudanminami  35.694003
# 11     Italian/French          Tōkyō-to Chiyoda-ku Kudanminami  35.694003
# 12     Italian/French             Tōkyō-to Minato-ku Shibakōen  35.658068
# 13     Italian/French             Tōkyō-to Minato-ku Shibakōen  35.658068
# 14     Italian/French             Tōkyō-to Minato-ku Shibakōen  35.658068
# 15     Italian/French             Tōkyō-to Minato-ku Shibakōen  35.658068
# 16     Italian/French             Tōkyō-to Minato-ku Shibakōen  35.658068
# 17     Italian/French             Tōkyō-to Minato-ku Shibakōen  35.658068
# 18     Italian/French             Tōkyō-to Minato-ku Shibakōen  35.658068
# 19     Italian/French             Tōkyō-to Minato-ku Shibakōen  35.658068
# 20     Italian/French             Tōkyō-to Minato-ku Shibakōen  35.658068
# 21     Italian/French             Tōkyō-to Minato-ku Shibakōen  35.658068
# 22     Italian/French             Tōkyō-to Minato-ku Shibakōen  35.658068
# 23     Italian/French             Tōkyō-to Minato-ku Shibakōen  35.658068
# 24     Italian/French             Tōkyō-to Minato-ku Shibakōen  35.658068
# 25     Italian/French             Tōkyō-to Minato-ku Shibakōen  35.658068
# 26     Italian/French             Tōkyō-to Minato-ku Shibakōen  35.658068
# 27     Italian/French             Tōkyō-to Minato-ku Shibakōen  35.658068
# 28     Italian/French             Tōkyō-to Minato-ku Shibakōen  35.658068
# 29     Italian/French             Tōkyō-to Minato-ku Shibakōen  35.658068
# ...               ...                                      ...        ...
# 29800           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29801           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29802           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29803           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29804           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29805           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29806           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29807           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29808           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29809           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29810           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29811           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29812           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29813           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29814           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29815           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29816           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29817           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29818           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29819           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29820           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29821           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29822           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29823           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29824           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29825           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29826           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29827           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29828           Other  Shizuoka-ken Hamamatsu-shi Motoshirochō  34.710895
# 29829  Italian/French             Hyōgo-ken Kōbe-shi Kumoidōri  34.695124
#
#         longitude          hpg_store_id  date_diff hpg_genre_name  \
# 0      139.753595  hpg_fbe603376b5980fc        NaN            NaN
# 1      139.753595  hpg_fbe603376b5980fc        NaN            NaN
# 2      139.753595  hpg_fbe603376b5980fc        NaN            NaN
# 3      139.753595  hpg_fbe603376b5980fc        NaN            NaN
# 4      139.753595  hpg_fbe603376b5980fc        NaN            NaN
# 5      139.753595  hpg_fbe603376b5980fc        NaN            NaN
# 6      139.753595  hpg_fbe603376b5980fc        NaN            NaN
# 7      139.753595  hpg_fbe603376b5980fc        NaN            NaN
# 8      139.753595  hpg_fbe603376b5980fc        NaN            NaN
# 9      139.753595  hpg_fbe603376b5980fc        NaN            NaN
# 10     139.753595  hpg_fbe603376b5980fc        NaN            NaN
# 11     139.753595  hpg_fbe603376b5980fc        NaN            NaN
# 12     139.751599                   NaN        NaN            NaN
# 13     139.751599                   NaN        NaN            NaN
# 14     139.751599                   NaN        NaN            NaN
# 15     139.751599                   NaN        NaN            NaN
# 16     139.751599                   NaN        NaN            NaN
# 17     139.751599                   NaN        NaN            NaN
# 18     139.751599                   NaN        NaN            NaN
# 19     139.751599                   NaN        NaN            NaN
# 20     139.751599                   NaN        NaN            NaN
# 21     139.751599                   NaN        NaN            NaN
# 22     139.751599                   NaN        NaN            NaN
# 23     139.751599                   NaN        NaN            NaN
# 24     139.751599                   NaN        NaN            NaN
# 25     139.751599                   NaN        NaN            NaN
# 26     139.751599                   NaN        NaN            NaN
# 27     139.751599                   NaN        NaN            NaN
# 28     139.751599                   NaN        NaN            NaN
# 29     139.751599                   NaN        NaN            NaN
# ...           ...                   ...        ...            ...
# 29800  137.725940  hpg_6507818140022452        NaN            NaN
# 29801  137.725940  hpg_6507818140022452        NaN            NaN
# 29802  137.725940  hpg_6507818140022452        NaN            NaN
# 29803  137.725940  hpg_6507818140022452        NaN            NaN
# 29804  137.725940  hpg_6507818140022452        NaN            NaN
# 29805  137.725940  hpg_6507818140022452        NaN            NaN
# 29806  137.725940  hpg_6507818140022452        NaN            NaN
# 29807  137.725940  hpg_6507818140022452        NaN            NaN
# 29808  137.725940  hpg_6507818140022452        NaN            NaN
# 29809  137.725940  hpg_6507818140022452        NaN            NaN
# 29810  137.725940  hpg_6507818140022452        NaN            NaN
# 29811  137.725940  hpg_6507818140022452        NaN            NaN
# 29812  137.725940  hpg_6507818140022452        NaN            NaN
# 29813  137.725940  hpg_6507818140022452        NaN            NaN
# 29814  137.725940  hpg_6507818140022452        NaN            NaN
# 29815  137.725940  hpg_6507818140022452        NaN            NaN
# 29816  137.725940  hpg_6507818140022452        NaN            NaN
# 29817  137.725940  hpg_6507818140022452        NaN            NaN
# 29818  137.725940  hpg_6507818140022452        NaN            NaN
# 29819  137.725940  hpg_6507818140022452        NaN            NaN
# 29820  137.725940  hpg_6507818140022452        NaN            NaN
# 29821  137.725940  hpg_6507818140022452        NaN            NaN
# 29822  137.725940  hpg_6507818140022452        NaN            NaN
# 29823  137.725940  hpg_6507818140022452        NaN            NaN
# 29824  137.725940  hpg_6507818140022452        NaN            NaN
# 29825  137.725940  hpg_6507818140022452        NaN            NaN
# 29826  137.725940  hpg_6507818140022452        NaN            NaN
# 29827  137.725940  hpg_6507818140022452        NaN            NaN
# 29828  137.725940  hpg_6507818140022452        NaN            NaN
# 29829  135.197852                   NaN        NaN            NaN
#
#       hpg_area_name
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# 27              NaN
# 28              NaN
# 29              NaN
# ...             ...
# 29800           NaN
# 29801           NaN
# 29802           NaN
# 29803           NaN
# 29804           NaN
# 29805           NaN
# 29806           NaN
# 29807           NaN
# 29808           NaN
# 29809           NaN
# 29810           NaN
# 29811           NaN
# 29812           NaN
# 29813           NaN
# 29814           NaN
# 29815           NaN
# 29816           NaN
# 29817           NaN
# 29818           NaN
# 29819           NaN
# 29820           NaN
# 29821           NaN
# 29822           NaN
# 29823           NaN
# 29824           NaN
# 29825           NaN
# 29826           NaN
# 29827           NaN
# 29828           NaN
# 29829           NaN
#
# [29830 rows x 12 columns]

# %%
full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29830 entries, 0 to 29829
# Data columns (total 12 columns):
# air_store_id        29830 non-null object
# vd                  29830 non-null object
# res_date_diff       29830 non-null int64
# reserve_visitors    29830 non-null int64
# air_genre_name      29830 non-null object
# air_area_name       29830 non-null object
# latitude            29830 non-null float64
# longitude           29830 non-null float64
# hpg_store_id        12646 non-null object
# date_diff           0 non-null float64
# hpg_genre_name      0 non-null object
# hpg_area_name       0 non-null object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 3.0+ MB

# %% [markdown]
# Missing Values Now we can start the analysis by looking at the percentage of missing values in each column. Missing values are fine when we do Exploratory Data Analysis, but they will have to be filled in for machine learning methods.  Following is a function that calculates the number of missing values and the percentage of the total values that are missing for each column. As with many tasks in data science, I did not write this function myself, but rather found it online in a Stack Overflow forum!

# %% [markdown]
# ## Geography clustering

# %% [markdown]
# Apparently Japan's terittory is divided in 8 regions which are not official administrative units, but have been traditionally used as the regional division of Japan in a number of contexts [https://en.wikipedia.org/wiki/List_of_regions_of_Japan ]
#
# From north to south, the traditional regions are:
# * **Hokkaidō** (the island of Hokkaidō and nearby islands, population: 5,507,456, largest city: Sapporo)
# * **Tōhoku** region (northern Honshū, population: 9,335,088, largest city: Sendai)
# * **Kantō** region (eastern Honshū, population: 42,607,376, largest city: Tokyo)
# * **Chūbu region** (central Honshū, including Mt. Fuji, population: 21,714,995, largest city: Nagoya), sometimes divided into:
#    * Hokuriku region (northwestern Chūbu, largest city: Kanazawa)
#    * Kōshin'etsu region (northeastern Chūbu, largest city: Niigata)
#   * Tōkai region (southern Chūbu, largest city: Nagoya)
# * **Kansai or Kinki** region (west-central Honshū, including the old capital, Kyoto, population: 22,755,030, largest city: Osaka)
# * **Chūgoku** region (western Honshū, population: 7,561,899, largest city: Hiroshima)
# * **Shikoku** (island, population: 3,977,205, largest city: Matsuyama)
# * **Kyūshū** (island, population: 14,596,977, largest city: Fukuoka) which includes:
#   * Northern Kyushu: Fukuoka, Saga, Nagasaki and Ōita (largest city: Fukuoka)
#   * Southern Kyushu: Kumamoto, Miyazaki and Kagoshima (largest city: Kagoshima)
#   * Okinawa (largest city: Naha)

# %%
#we do cluster analysis by geographic position(Longitude,Latitude)
#the number of classes is equal to 9 because in Japan there are 9 areas(n_clusters=8)
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=8, random_state=0).fit(full[['longitude','latitude']])
full['cluster'] = kmeans.predict(full[['longitude','latitude']])

# %%
full.head()
# Out:
#            air_store_id          vd  res_date_diff  reserve_visitors  \
# 0  air_00a91d42b08b08d9  2016-10-31              0                 2
# 1  air_00a91d42b08b08d9  2016-12-05              4                 9
# 2  air_00a91d42b08b08d9  2016-12-14              6                18
# 3  air_00a91d42b08b08d9  2016-12-17              6                 2
# 4  air_00a91d42b08b08d9  2016-12-20              2                 4
#
#    air_genre_name                    air_area_name   latitude   longitude  \
# 0  Italian/French  Tōkyō-to Chiyoda-ku Kudanminami  35.694003  139.753595
# 1  Italian/French  Tōkyō-to Chiyoda-ku Kudanminami  35.694003  139.753595
# 2  Italian/French  Tōkyō-to Chiyoda-ku Kudanminami  35.694003  139.753595
# 3  Italian/French  Tōkyō-to Chiyoda-ku Kudanminami  35.694003  139.753595
# 4  Italian/French  Tōkyō-to Chiyoda-ku Kudanminami  35.694003  139.753595
#
#            hpg_store_id  date_diff hpg_genre_name hpg_area_name  cluster
# 0  hpg_fbe603376b5980fc        NaN            NaN           NaN        3
# 1  hpg_fbe603376b5980fc        NaN            NaN           NaN        3
# 2  hpg_fbe603376b5980fc        NaN            NaN           NaN        3
# 3  hpg_fbe603376b5980fc        NaN            NaN           NaN        3
# 4  hpg_fbe603376b5980fc        NaN            NaN           NaN        3

# %%
f,axa = plt.subplots(1,2,figsize=(15,6))
hist_clust = full.groupby(['cluster'],as_index=False).count()
sns.barplot(x=hist_clust.cluster,y=hist_clust.air_store_id,ax=axa[0])
sns.barplot(x=hist_clust.cluster,y=hist_clust.hpg_store_id,ax=axa[1])
plt.show()

# %%
#we import the library "Basemap" from mpl_toolkits.basemap and projection to create a map
import os
os.environ["PROJ_LIB"] = "C:\\Users\\sergey\\Anaconda3\\Library\\share";
from mpl_toolkits.basemap import Basemap
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-115-2205b8550a23> in <module>
#       2 import os
#       3 os.environ["PROJ_LIB"] = "C:\\Users\\sergey\\Anaconda3\\Library\\share";
# ----> 4 from mpl_toolkits.basemap import Basemap
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'

# %%
#separate the first part of the name of the region
full['prefecture'] = full['air_area_name'].map(lambda x: str(x).split(' ')[0])
full.head(1)

# %%
aircluster = full.groupby(['prefecture','cluster',], as_index=False)['air_store_id'].count()
aircluster['percent'] = aircluster.air_store_id/aircluster.air_store_id.sum()*100
aircluster.head(10)
#we calculate what percentage of all restaurants are in each region

# %% [markdown]
# Let's try to relate the identified groups with the biggest cities:
#
# * Cluster 0 refers to Hiroshima-ken.
# * Cluster 1 refers  to Niigata-ken
# * Cluster 2 refers to Hokkaidō
# * Cluster 3 refers to Tōkyō-to
# * Cluster 4 refers to Hyōgo-ken
# * Cluster 5 referst to Fukuoka-ken
# * Cluster 6 refers to Shizuoka-ken
# * Cluster 7 refers to Miyagi-ken

# %%
aircluster.air_store_id.sum()

# %% [markdown]
# ## Japanese Holidays and date conversion

# %% [markdown]
#   At the stage ofdata analysis(EDA), we see that one of the important factors affecting the attendance of restaurants are day of the week, month and holidays.

# %% [markdown]
# I want to learn more about that so I will rely on this list https://www.officeholidays.com/countries/japan/index.php
#
# * Jan 1st - **New Years day**;
# * 2nd Monday of January - **Coming of Age day **: The day honors young Japanese who will reach the age of 20 at any point during the year. Twenty is the age of majority in Japan, and people who have reached this age gain the right to vote in elections as well as to drink;
# * Feb 11th - **National Foundation day**:  a national holiday for Japanese people to remind themselves of the nation's founding and foster their love for the nation;
# * March 20th or 21st- **Vernal Equinox day**: The day is intended to celebrate the love of nature and living things.In modern Japan, the day still maintains its older traditions as visiting family graves and holding family reunions is a common way of celebrating the equinox;
# * April 29th - ** Showa day**: Showa Day honours the birthday of Emperor Hirohito, the reigning Emperor before, during, and after World War II (from 1926 - 1989);

# %%
#dates.rename(columns={'calendar_date':'visit_date'})
dates['visit_date']=dates['calendar_date']
dates.head(3)

# %%
dates.drop(['calendar_date'], axis=1, inplace=True)

# %%
full.drop(['hpg_store_id','date_diff','hpg_genre_name','hpg_area_name','air_area_name'], axis=1, inplace=True)

# %%
full.head(1)

# %%
full['vd'] = pd.to_datetime(full['vd'])

# %%
full['month'] = full['vd'].dt.month 
full['date'] = full['vd'].dt.day
full['dw'] = full['vd'].dt.dayofweek
full['dy'] = full['vd'].dt.dayofyear
full.head()

# %%
dates['visit_date'] = pd.to_datetime(dates['visit_date'])

# %%
#full.drop(['vd'], axis=1, inplace=True)

# %%
nf = pd.merge(full, dates, how='left', on=['visit_date']) 
#nf = pd.merge(full,dates,on='visit_date', how='outer', validate="many_to_one")
nf.head()
#pd.merge(left, right, on='B', how='outer', validate="one_to_one")

# %%
nf.info()

# %%
#we assign indexes for holiday, sunday, saturday.
nf['sunday'] = nf['visit_date'].dt.dayofweek.apply(lambda x:1 if x==6 else 0)
nf['saturday'] = nf['visit_date'].dt.dayofweek.apply(lambda x:1 if x==5 else 0)
nf['sat/sun/hol']=nf['holiday_flg']*1+nf['sunday']*0.5+nf['saturday']*0.3

nf2016 = nf[nf['visit_date'].dt.year==2016]
nf2017 = nf[nf['visit_date'].dt.year==2017]
nf.head()

# %% [markdown]
# We can check how many days before the visit japenese people make the reservation.

# %%
nf.res_date_diff.describe()

# %% [markdown]
# ## Weather Data

# %%
wd.head()

# %%
#separate the first part of the name of the region
wd['prefecture'] = wd['area_name'].map(lambda x: str(x).split('_')[0])
wd.head(1)

# %%
wdmytest = wd.groupby(['prefecture'], as_index=False)['avg_temperature'].mean()
wdmytest.head(10)

# %% [markdown]
# Let's try to relate the identified groups with the biggest cities:
#
# * Cluster 0 refers to Hiroshima-ken.+
# * Cluster 1 refers  to Niigata-ken+
# * Cluster 2 refers to Hokkaidō+
# * Cluster 3 refers to Tōkyō-to+
# * Cluster 4 refers to Hyōgo-ken
# * Cluster 5 referst to Fukuoka-ken+
# * Cluster 6 refers to Shizuoka-ken+
# * Cluster 7 refers to Miyagi-ken+

# %%
import re
def area2group(area):
    if re.match(r'tokyo.*',area) !=None:
        return 3
    if re.match(r'hyogo.*',area) !=None:
        return 4
    if re.match(r'hokkaido.*',area) !=None:
        return 2    
    if re.match(r'fukuoka.*',area) !=None:
        return 5
    if re.match(r'niigata.*',area) !=None:
        return 1
    if re.match(r'hiroshima.*',area) !=None:
        return 0
    if re.match(r'shizuoka.*',area) !=None:
        return 6
    if re.match(r'miyagi.*',area) !=None:
        return 7
    else:
        return -1

warea = [area2group(area) for area in wd.area_name]
wd['cluster'] = warea
#re.match(r'fukuoka.*',wd.area_name[0])
#wd.area_name

# %%
wd['calendar_date'] = pd.to_datetime(wd.calendar_date).dt.date

# %%
wdg = wd.groupby(['cluster','calendar_date'],as_index=False).mean()
wdg.head()

# %%
nf['visit_date']=pd.to_datetime(nf.visit_date).dt.date
nf.head(1)

# %%
wnf = pd.merge(wdg,nf,left_on=['cluster','calendar_date'],right_on=['cluster','visit_date'])
wnf.head()

# %%
airvisit.head()

# %%
airvisit['visit_date'] = pd.to_datetime(airvisit['visit_date']).dt.date
wnf = pd.merge(wnf,airvisit,on=['air_store_id','visit_date'])

# %%
wnf.head()

# %%
wnf.info()

# %%
f,axa = plt.subplots(1,1,figsize=(15,10))
sns.heatmap(wnf.corr()[['visitors']])

# %% [markdown]
# Apparently there number of visitors is not correlated with the weather conditions
